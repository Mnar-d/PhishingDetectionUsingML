# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from __future__ import print_function

# read in the iris data
# from sklearn.datasets import load_iris
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
# iris = load_iris()

# %%
df=pd.read_csv('Phishing_Legitimate_full.csv')

# %%
df.head()
# Out:
#    id  NumDots  ...  PctExtNullSelfRedirectHyperlinksRT  CLASS_LABEL
# 0   1        3  ...                                   1            1
# 1   2        3  ...                                   1            1
# 2   3        3  ...                                   0            1
# 3   4        3  ...                                  -1            1
# 4   5        3  ...                                  -1            1
#
# [5 rows x 50 columns]

# %%
df.shape
# Out:
# (10000, 50)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 50 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  10000 non-null  int64
#  1   NumDots                             10000 non-null  int64
#  2   SubdomainLevel                      10000 non-null  int64
#  3   PathLevel                           10000 non-null  int64
#  4   UrlLength                           10000 non-null  int64
#  5   NumDash                             10000 non-null  int64
#  6   NumDashInHostname                   10000 non-null  int64
#  7   AtSymbol                            10000 non-null  int64
#  8   TildeSymbol                         10000 non-null  int64
#  9   NumUnderscore                       10000 non-null  int64
#  10  NumPercent                          10000 non-null  int64
# ...

# %%
df.isna()
# Out:
#          id  NumDots  ...  PctExtNullSelfRedirectHyperlinksRT  CLASS_LABEL
# 0     False    False  ...                               False        False
# 1     False    False  ...                               False        False
# 2     False    False  ...                               False        False
# 3     False    False  ...                               False        False
# 4     False    False  ...                               False        False
# ...     ...      ...  ...                                 ...          ...
# 9995  False    False  ...                               False        False
# 9996  False    False  ...                               False        False
# 9997  False    False  ...                               False        False
# 9998  False    False  ...                               False        False
# 9999  False    False  ...                               False        False
#
# [10000 rows x 50 columns]

# %%
df.rename(columns={'CLASS_LABEL': 'LABEL'}, inplace=True)

# %%
float_cols = df.select_dtypes('float64').columns
for c in float_cols:
    df[c] = df[c].astype('float32')
    
int_cols = df.select_dtypes('int64').columns
for c in int_cols:
    df[c] = df[c].astype('int32')
    
df.info()

# %%
df.UrlLength.mean()
# Out:
# 70.2641

# %%
df.drop('id',axis=1,inplace=True)

# %%
df.LABEL.value_counts()
unique=df.nunique().sort_values(ascending=True).reset_index()
# unique

# %%
df.shape
# Out:
# (10000, 49)

# %%
df.describe()
# Out:
#             NumDots  ...         LABEL
# count  10000.000000  ...  10000.000000
# mean       2.445100  ...      0.500000
# std        1.346836  ...      0.500025
# min        1.000000  ...      0.000000
# 25%        2.000000  ...      0.000000
# 50%        2.000000  ...      0.500000
# 75%        3.000000  ...      1.000000
# max       21.000000  ...      1.000000
#
# [8 rows x 49 columns]

# %%
# def cm_to_inch(value):
    #return value/2.54
f = plt.figure()
f.set_figwidth(100)
f.set_figheight(30)

plt.plot(df)
# plt.figure(figsize=(cm_to_inch(150),cm_to_inch(100)))
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py'>

# %%
df['LABEL'].value_counts().plot(kind='bar')

# %%
X = df ['LABEL']
Y  = df ['NumDots']
plt.scatter(X, Y, label = 'm',color='b', marker='s')
plt.xlabel('Lable')
plt.ylabel('Number of Dots')
#plt.xticks(month)
plt.title('Number of Dot Vs Label')
#plt.yticks([100000, 200000, 300000, 400000, 500000])
plt.show();

# %%
X = df ['LABEL']
Y  = df ['NumSensitiveWords']
plt.scatter(X, Y, label = 'm',color='b', marker='s')
plt.xlabel('Lable')
plt.ylabel('Number Sensitive Words')
#plt.xticks(month)
plt.title('Number Sensitive Words Vs Label')
#plt.yticks([100000, 200000, 300000, 400000, 500000])
plt.show();

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 2)

# %%
print(X_train )
# Out:
#       NumDots  ...  PctExtNullSelfRedirectHyperlinksRT
# 2753        3  ...                                  -1
# 2824        2  ...                                  -1
# 2597        3  ...                                  -1
# 3973        2  ...                                   1
# 3335        2  ...                                  -1
# ...       ...  ...                                 ...
# 1099        2  ...                                   1
# 2514        4  ...                                  -1
# 6637        2  ...                                   1
# 2575        3  ...                                  -1
# 7336        1  ...                                   1
#
# [7500 rows x 48 columns]

# %%
print(y_train)
# Out:
# 2753    1
# 2824    1
# 2597    1
# 3973    1
# 3335    1
#        ..
# 1099    1
# 2514    1
# 6637    0
# 2575    1
# 7336    0
# Name: LABEL, Length: 7500, dtype: int64

# %%
print(X_test)
# Out:
#       NumDots  ...  PctExtNullSelfRedirectHyperlinksRT
# 7878        1  ...                                   0
# 3224        2  ...                                  -1
# 1919        2  ...                                  -1
# 4432        2  ...                                   1
# 4835        3  ...                                  -1
# ...       ...  ...                                 ...
# 8042        1  ...                                   1
# 9060        1  ...                                   1
# 8093        1  ...                                   1
# 3858        2  ...                                  -1
# 7767        1  ...                                   1
#
# [2500 rows x 48 columns]

# %%
print(y_test)
# Out:
# 7878    0
# 3224    1
# 1919    1
# 4432    1
# 4835    1
#        ..
# 8042    0
# 9060    0
# 8093    0
# 3858    1
# 7767    0
# Name: LABEL, Length: 2500, dtype: int64

# %%
# data type of the colum
# df.NumDots.dtype

# %%
# fun compare

# %%
# def corr_heatmap(df, idx_s, idx_e):
   #  y = df['CLASS_LABEL']
    # temp = df.iloc[:, idx_s:idx_e]
    # if 'id' in temp.columns:
    #     del temp['id']
    # temp['CLASS_LABEL'] = y
    # sns.heatmap(temp.corr(), annot=True, fmt='.2f')
    # plt.show()

# %%
# corr_heatmap(df, 0, 10)

# %%
df['LABEL'].value_counts().plot(kind='bar')

# %%
# create X (features) and y (response)
# X = df.data
# y = df.target

# %%
# print the shapes of X and y
# print(X.shape)
# print(y.shape)

# %%
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# %%
# print(X_train.shape)
# print(X_test.shape)

# %%
plt.plot(df)

# %%
x = df['NumDots','NumDots','SubdomainLevel','PathLevel','UrlLength','NumDash']
